# %%
# import needed packages
import pandas as pd

# %%
# import dataset - PlaneFeatures.xlsx
planeFeatures = pd.read_excel(r'data/PlaneFeatures.xlsx')

# %%
# import dataset - PlaneCandidates.xlsx
planeCandidates = pd.read_excel(r'data/PlaneCandidates.xlsx')

# %%
# view the dataset
planeFeatures.head(10)
# Out:
#    adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 0       A   0.120253   0.075949   0.183544   0.335443   0.284810  0.088608
# 1  A00000   0.211735   0.155612   0.181122   0.198980   0.252551  0.204082
# 2  A00002   0.517241   0.103448   0.103448   0.103448   0.172414  0.862069
# 3  A00008   0.125000   0.041667   0.208333   0.166667   0.458333  0.125000
# 4  A0001E   0.100000   0.200000   0.200000   0.400000   0.100000  0.100000
# 5  A0002B   0.166667   0.166667   0.000000   0.666667   0.000000  0.333333
# 6  A00049   0.186441   0.118644   0.288136   0.169492   0.237288  0.152542
# 7  A00063   0.214286   0.142857   0.285714   0.285714   0.071429  0.250000
# 8  A00076   0.333333   0.266667   0.222222   0.155556   0.022222  0.466667
# 9  A0007A   0.103448   0.396552   0.275862   0.103448   0.120690  0.086207
#
#      boxes2    boxes3    boxes4  ...    steer3    steer4    steer5    steer6  \
# ...

# %%
planeCandidates.head(10)
# Out:
#     other  surveil  adshex  squawk_1                                    name  \
# 0  0.0750   0.9250  A4FB3C      5310                    CITY OF MESA ARIZONA
# 1  0.0995   0.9005  A13098      4415                                     NaN
# 2  0.1010   0.8990  A7D925       230  ORANGE COUNTY SHERIFFS DEPARTMENT RNSP
# 3  0.1085   0.8915  A63E52      5306                     CHAPARRAL AIR GROUP
# 4  0.1230   0.8770  A1B621      5240                   MIDWEST AIRMOTIVE INC
# 5  0.1370   0.8630  A005D8      5011                                     NaN
# 6  0.1415   0.8585  A144AF      5103                                     NaN
# 7  0.1585   0.8415  A4F784      5101                                     NaN
# 8  0.1615   0.8385  A565E6      5106                    ROOS GERHARDT PIETER
# 9  0.1625   0.8375  A497C0      5367                              SCIFLY LLC
#
#       reg
# 0   N42WB
# 1     NaN
# 2  N6045C
# 3  N501GW
# 4  N2092S
# 5     NaN
# 6     NaN
# 7     NaN
# 8  N447PC
# ...

# %%
# merge the datasets
planes = pd.merge(planeFeatures, planeCandidates)

# %%
# view the result
planes.head(10)
# Out:
#    adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 0  A00324   0.000000   0.000000   0.000000   0.235294   0.764706  0.000000
# 1  A005D8   0.241379   0.137931   0.137931   0.103448   0.379310  0.241379
# 2  A008A4   0.279570   0.112903   0.134409   0.118280   0.354839  0.263441
# 3  A00948   0.090909   0.545455   0.272727   0.090909   0.000000  0.272727
# 4  A00A41   0.000000   0.536585   0.195122   0.073171   0.195122  0.695122
# 5  A0371C   0.563291   0.272152   0.075949   0.044304   0.044304  0.841772
# 6  A067A2   0.461538   0.153846   0.153846   0.076923   0.153846  0.615385
# 7  A0761C   0.310811   0.557432   0.081081   0.043919   0.006757  0.702703
# 8  A07BEE   0.059347   0.050445   0.106825   0.100890   0.682493  0.077151
# 9  A07CB3   0.411765   0.176471   0.176471   0.058824   0.176471  0.176471
#
#      boxes2    boxes3    boxes4  ...    steer7    steer8  flights  squawk_1  \
# ...
