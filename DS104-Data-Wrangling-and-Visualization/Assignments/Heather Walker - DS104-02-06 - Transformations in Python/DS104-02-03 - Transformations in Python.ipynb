# %%
# import needed packages
import pandas as pd

# %%
# import dataset
energy = pd.read_excel(r'data/energy.xlsx')

# %%
# view first rows of dataframe
energy.head(10)
# Out:
#    Year  ResidentPopulation   GDP  HouseholdSize  MedianIncome  \
# 0  1984              235.83  3.93           2.69         44.80
# 1  1985              237.92  4.22           2.67         45.64
# 2  1986              240.13  4.46           2.66         47.26
# 3  1987              242.29  4.74           2.64         47.85
# 4  1988              244.50  5.10           2.62         48.22
# 5  1989              246.82  5.48           2.63         49.08
# 6  1990              249.62  5.80           2.63         48.42
# 7  1991              252.98  5.99           2.62         47.03
# 8  1992              256.51  6.34           2.66         46.65
# 9  1993              259.92  6.67           2.67         46.42
#
#    CostResidentialElectric  CostResidentialGas  CostResidentialOil  \
# 0                    20.17                5.72                7.57
# 1                    20.13                5.52                7.06
# 2                    19.84                5.17                5.50
# ...

# %%
# transpose while renaming the columns with `set_index()`
energy2 = energy.set_index('Year').T

# %%
# view result
energy2
# Out:
# Year                            1984    1985    1986    1987    1988    1989  \
# ResidentPopulation            235.83  237.92  240.13  242.29  244.50  246.82
# GDP                             3.93    4.22    4.46    4.74    5.10    5.48
# HouseholdSize                   2.69    2.67    2.66    2.64    2.62    2.63
# MedianIncome                   44.80   45.64   47.26   47.85   48.22   49.08
# CostResidentialElectric        20.17   20.13   19.84   19.22   18.53   18.08
# CostResidentialGas              5.72    5.52    5.17    4.73    4.49    4.41
# CostResidentialOil              7.57    7.06    5.50    5.10    4.96    5.23
# ResidentialEnergyConsumption   15.96   16.04   15.98   16.26   17.13   17.79
#
# Year                            1990    1991    1992    1993  ...    2001  \
# ResidentPopulation            249.62  252.98  256.51  259.92  ...  285.08
# GDP                             5.80    5.99    6.34    6.67  ...   10.29
# ...

# %%
# transpose back to original form
energy3 = energy2.T

# %%
energy3.head(10)
# Out:
#       ResidentPopulation   GDP  HouseholdSize  MedianIncome  \
# Year
# 1984              235.83  3.93           2.69         44.80
# 1985              237.92  4.22           2.67         45.64
# 1986              240.13  4.46           2.66         47.26
# 1987              242.29  4.74           2.64         47.85
# 1988              244.50  5.10           2.62         48.22
# 1989              246.82  5.48           2.63         49.08
# 1990              249.62  5.80           2.63         48.42
# 1991              252.98  5.99           2.62         47.03
# 1992              256.51  6.34           2.66         46.65
# 1993              259.92  6.67           2.67         46.42
#
#       CostResidentialElectric  CostResidentialGas  CostResidentialOil  \
# Year
# 1984                    20.17                5.72                7.57
# 1985                    20.13                5.52                7.06
# 1986                    19.84                5.17                5.50
# ...
